# %% [markdown]
# # Sample autodx usage
#
# Requires graphviz (`dot` executable) to be installed on your machine and also the python package installed with `pip install graphviz`. I had to do (on mac)
#
# ```bash
# brew install graphviz --with-pango
# ```
#
# to get the cairo support for subscripts in the graph visualizations.

# %%
#%matplotlib inline 

import autodx.forward_ast
import autodx.viz.forward
import graphviz

from IPython.display import Image, SVG, display_png, set_matplotlib_formats, display_pdf

# %%
import tempfile

x1 = autodx.forward_ast.Var(3)
x2 = autodx.forward_ast.Var(5)
y = x1 * x2 * 9
g = autodx.viz.forward.astviz(y, x2)
g

# %%
autodx.support.display(g)

# %% [raw]
# g = graphviz.Source("""
# digraph t {
#     fontnames="ps";
#     v5 [shape=box, color="#444443", margin="0.02", fontcolor="#444443", fontsize="13" fontname="Helvetica", style=filled, fillcolor="#fefecd", label=<<table BORDER="0" CELLPADDING="0" CELLBORDER="0" CELLSPACING="1">
#
#             <tr><td><font face="Helvetica" point-size="13">v</font><sub><font face="Helvetica" point-size="9">5</font></sub></td><td> = </td><td align="left"><font face="Helvetica" point-size="13">v</font><sub><font face="Helvetica" point-size="9">3</font></sub> &times; <font face="Helvetica" point-size="13">v</font><sub><font face="Helvetica" point-size="9">4</font></sub></td><td> = </td><td align="left">135</td></tr>
#
#                 <tr><td>    </td><td> = </td><td align="left"><font face="Helvetica" point-size="13">v</font><sub><font face="Helvetica" point-size="9">3</font></sub> &times; <font face="Helvetica" point-size="13">v</font><sub><font face="Helvetica" point-size="9">4</font></sub> + <font face="Helvetica" point-size="13">v</font><sub><font face="Helvetica" point-size="9">4</font></sub> &times; <font face="Helvetica" point-size="13">v</font><sub><font face="Helvetica" point-size="9">3</font></sub></td><td>=</td><td align="left">0 + 27 = 27</td></tr>
#
#     </table>
#     >];
# }
# """)
# g
